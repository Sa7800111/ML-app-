# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from pathlib import Path
DATA = Path(r"E:\Titanic\Data")

# %%
train  = pd.read_csv(DATA / "train.csv")
test   = pd.read_csv(DATA / "test.csv")
gender = pd.read_csv(DATA / "gender_submission.csv")

# %%
def missing_report(df):
    miss_cnt = df.isna().sum()
    miss_pct = df.isna().mean() * 100
    return pd.DataFrame({"missing_count": miss_cnt, "missing_percent": miss_pct}).sort_values("missing_percent", ascending=False)

# %%
print("Missing Data - Train")
print(missing_report(train))
print("\nMissing Data - Test")
print(missing_report(test))
# Out:
# Missing Data - Train
#              missing_count  missing_percent
# Cabin                  687        77.104377
# Age                    177        19.865320
# Embarked                 2         0.224467
# PassengerId              0         0.000000
# Name                     0         0.000000
# Pclass                   0         0.000000
# Survived                 0         0.000000
# Sex                      0         0.000000
# Parch                    0         0.000000
# SibSp                    0         0.000000
# Fare                     0         0.000000
# Ticket                   0         0.000000
#
# Missing Data - Test
#              missing_count  missing_percent
# Cabin                  327        78.229665
# Age                     86        20.574163
# Fare                     1         0.239234
# Name                     0         0.000000
# Pclass                   0         0.000000
# PassengerId              0         0.000000
# ...

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
mfare = test.loc[test["Fare"].isna()].copy()

# %%
mfare
# Out:
#      PassengerId  Pclass                Name   Sex   Age  SibSp  Parch Ticket  \
# 152         1044       3  Storey, Mr. Thomas  male  60.5      0      0   3701
#
#      Fare Cabin Embarked
# 152   NaN   NaN        S

# %%
mclass = test.loc[test["Pclass"] == 3].copy()
mclass
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                    Svensson, Mr. Johan Cervin
# ..           ...     ...                                           ...
# 412         1304       3                Henriksson, Miss. Jenny Lovisa
# 413         1305       3                            Spector, Mr. Woolf
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# ...

# %%
pclass3_mean_fare = mclass["Fare"].mean()

# %%
test.loc[test["PassengerId"] == 1044, "Fare"] = pclass3_mean_fare

# %%
row = test.set_index("PassengerId").loc[[1044]] 
print(row.to_string())
# Out:
#              Pclass                Name   Sex   Age  SibSp  Parch Ticket       Fare Cabin Embarked
# PassengerId
# 1044              3  Storey, Mr. Thomas  male  60.5      0      0   3701  12.459678   NaN        S

# %%
test.drop(columns=["SibSp", "Parch", "Cabin"], inplace=True, errors="ignore")

# %%
print(test.columns.tolist())
# Out:
# ['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'Ticket', 'Fare', 'Embarked']

# %%
male_test = test.loc[test["Sex"] == "male"].copy()
female_test = test.loc[test["Sex"] == "female"].copy()

# %%
male_test.head()
# Out:
#    PassengerId  Pclass                          Name   Sex   Age  Ticket  \
# 0          892       3              Kelly, Mr. James  male  34.5  330911
# 2          894       2     Myles, Mr. Thomas Francis  male  62.0  240276
# 3          895       3              Wirz, Mr. Albert  male  27.0  315154
# 5          897       3    Svensson, Mr. Johan Cervin  male  14.0    7538
# 7          899       2  Caldwell, Mr. Albert Francis  male  26.0  248738
#
#       Fare Embarked
# 0   7.8292        Q
# 2   9.6875        Q
# 3   8.6625        S
# 5   9.2250        S
# 7  29.0000        S

# %%
female_test.head()
# Out:
#     PassengerId  Pclass                                           Name  \
# 1           893       3               Wilkes, Mrs. James (Ellen Needs)
# 4           896       3   Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 6           898       3                           Connolly, Miss. Kate
# 8           900       3      Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 12          904       1  Snyder, Mrs. John Pillsbury (Nelle Stevenson)
#
#        Sex   Age   Ticket     Fare Embarked
# 1   female  47.0   363272   7.0000        S
# 4   female  22.0  3101298  12.2875        S
# 6   female  30.0   330972   7.6292        Q
# 8   female  18.0     2657   7.2292        C
# 12  female  23.0    21228  82.2667        S

# %%
male_missing_age_test= male_test["Age"].isna().sum()  
male_missing_age_test= int(male_missing_age_test)
male_missing_age_test
# Out:
# 61

# %%
female_missing_age_test = female_test["Age"].isna().sum()
female_missing_age_test = int(female_missing_age_test)
female_missing_age_test
# Out:
# 25

# %%
age_mode_test_male = test.loc[test["Sex"] == "male", "Age"].dropna().mode().iloc[0]
age_mode_test_female = test.loc[test["Sex"] == "female", "Age"].dropna().mode().iloc[0]

# %%
test.loc[(test["Sex"] == "male") & (test["Age"].isna()), "Age"] = age_mode_test_male
test.loc[(test["Sex"] == "female") & (test["Age"].isna()), "Age"] = age_mode_test_female

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age   Ticket     Fare Embarked
# 0  34.5   330911   7.8292        Q
# 1  47.0   363272   7.0000        S
# 2  62.0   240276   9.6875        Q
# 3  27.0   315154   8.6625        S
# 4  22.0  3101298  12.2875        S

# %%
test.isna().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
test.to_csv(r"E:\Titanic\Data\test_new.csv")

# %%
new = pd.read_csv(r"E:\Titanic\Data\test_new.csv")

# %%
new
# Out:
#      Unnamed: 0  PassengerId  Pclass  \
# 0             0          892       3
# 1             1          893       3
# 2             2          894       2
# 3             3          895       3
# 4             4          896       3
# ..          ...          ...     ...
# 413         413         1305       3
# 414         414         1306       1
# 415         415         1307       3
# 416         416         1308       3
# 417         417         1309       3
#
#                                              Name     Sex   Age  \
# 0                                Kelly, Mr. James    male  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..                                            ...     ...   ...
# ...

# %%
new.isna().sum()
# Out:
# Unnamed: 0     0
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train = train.drop(columns=["Cabin"], errors="ignore")

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
missing_embarked = train.loc[train["Embarked"].isna() | (train["Embarked"] == "")]

# %%
missing_embarked
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Embarked
# 61   female  38.0      0      0  113572  80.0      NaN
# 829  female  62.0      0      0  113572  80.0      NaN

# %%
train.loc[train["PassengerId"].isin([62, 830]), "Embarked"] = "S"

# %%
train.loc[[61, 829], ["PassengerId","Name","Fare","Embarked"]]
# Out:
#      PassengerId                                       Name  Fare Embarked
# 61            62                        Icard, Miss. Amelie  80.0        S
# 829          830  Stone, Mrs. George Nelson (Martha Evelyn)  80.0        S

# %%
age_mode_train = train["Age"].dropna().mode().iloc[0]
train["Age"].fillna(age_mode_train, inplace=True)
# Out:
# C:\Users\CORE I5\AppData\Local\Temp\ipykernel_63952\3374189923.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train["Age"].fillna(age_mode_train, inplace=True)

# %%
train["Age"].isna().sum()
# Out:
# np.int64(0)

# %%
train.drop(columns=["SibSp", "Parch", "Cabin"], inplace=True, errors="ignore")

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %%
train.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
train_new = train.copy()

# %%
train_new.to_csv(r"E:\Titanic\Data\train_new.csv", index=False)

# %%
import pandas as pd
pd.read_csv(r"E:\Titanic\Data\train_new.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...
